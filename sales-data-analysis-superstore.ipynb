# %% [markdown]
# <a href="https://colab.research.google.com/github/karthipranav26/HR/blob/main/sales-data-analysis-superstore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("superstore_sales.csv", encoding="latin1")
df = df.drop_duplicates()
df = df.dropna(subset=["Sales", "Profit"])
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Year"] = df["Order Date"].dt.year
df["Month"] = df["Order Date"].dt.month_name()

sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# Sales by Region
region_sales = df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
sns.barplot(x=region_sales.index, y=region_sales.values)
plt.title("Total Sales by Region")
plt.show()
